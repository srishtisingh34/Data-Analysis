# %%
import pandas as pd

# %%
nba = pd.read_csv("nba.csv")
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
nba.index
# Out:
# RangeIndex(start=0, stop=458, step=1)

# %%
nba.values
# Out:
# array([['Avery Bradley', 'Boston Celtics', 0.0, ..., 180.0, 'Texas',
#         7730337.0],
#        ['Jae Crowder', 'Boston Celtics', 99.0, ..., 235.0, 'Marquette',
#         6796117.0],
#        ['John Holland', 'Boston Celtics', 30.0, ..., 205.0,
#         'Boston University', nan],
#        ...,
#        ['Tibor Pleiss', 'Utah Jazz', 21.0, ..., 256.0, nan, 2900000.0],
#        ['Jeff Withey', 'Utah Jazz', 24.0, ..., 231.0, 'Kansas', 947276.0],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=object)

# %%
nba.shape
# Out:
# (458, 9)

# %%
nba.dtypes.value_counts()
# Out:
# object     5
# float64    4
# dtype: int64

# %%
nba.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
nba.axes #gives respective range index and cols details
# Out:
# [RangeIndex(start=0, stop=458, step=1),
#  Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#         'College', 'Salary'],
#        dtype='object')]

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
rev=pd.read_csv("revenue.csv", index_col= "Date")
rev.head(3)
# Out:
#         New York  Los Angeles  Miami
# Date
# 1/1/16       985          122    499
# 1/2/16       738          788    534
# 1/3/16        14           20    933

# %%
s=pd.Series([1,2,3])
s.sum()
# Out:
# 6

# %%
rev.sum(axis="index") # gives sum as column wise
# Out:
# New York       5475
# Los Angeles    5134
# Miami          5641
# dtype: int64

# %%
rev.sum(axis= 1) #gives row wise sum
rev.sum(axis="columns") #Also gives sum row wise
# Out:
# Date
# 1/1/16     1606
# 1/2/16     2060
# 1/3/16      967
# 1/4/16     2519
# 1/5/16      438
# 1/6/16     1935
# 1/7/16     1234
# 1/8/16     2313
# 1/9/16     2623
# 1/10/16     555
# dtype: int64

# %%
nba.Name #returns or extracts the single column
nba.Number
# Out:
# 0       0.0
# 1      99.0
# 2      30.0
# 3      28.0
# 4       8.0
#        ...
# 453     8.0
# 454    25.0
# 455    21.0
# 456    24.0
# 457     NaN
# Name: Number, Length: 458, dtype: float64

# %%
nba["Name"]
nba["Salary"]
# Out:
# 0      7730337.0
# 1      6796117.0
# 2            NaN
# 3      1148640.0
# 4      5000000.0
#          ...
# 453    2433333.0
# 454     900000.0
# 455    2900000.0
# 456     947276.0
# 457          NaN
# Name: Salary, Length: 458, dtype: float64

# %%
nba[ ["Name","Team"]].sort_index(ascending=False)
nba[["Number", "College"]].tail(3)#extract two cols
# Out:
#      Number College
# 455    21.0     NaN
# 456    24.0  Kansas
# 457     NaN     NaN

# %%
nba.insert(3, column= "Sport", value = "Basketball")
nba.head(3) #Adding a new column in between a dataset
# Out:
#             Name            Team  Number       Sport  \
# 0  Avery Bradley  Boston Celtics     0.0  Basketball
# 1    Jae Crowder  Boston Celtics    99.0  Basketball
# 2   John Holland  Boston Celtics    30.0  Basketball
#
#                             League Position   Age Height  Weight  \
# 0  National Basketball Association       PG  25.0    6-2   180.0
# 1  National Basketball Association       SF  25.0    6-6   235.0
# 2  National Basketball Association       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba.head(3)
# Out:
#             Name            Team  Number       Sport  \
# 0  Avery Bradley  Boston Celtics     0.0  Basketball
# 1    Jae Crowder  Boston Celtics    99.0  Basketball
# 2   John Holland  Boston Celtics    30.0  Basketball
#
#                             League Position   Age Height  Weight  \
# 0  National Basketball Association       PG  25.0    6-2   180.0
# 1  National Basketball Association       SF  25.0    6-6   235.0
# 2  National Basketball Association       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba["Age"].add(5)#Broadcasting Operations
# Out:
# 0      30.0
# 1      30.0
# 2      32.0
# 3      27.0
# 4      34.0
#        ...
# 453    31.0
# 454    29.0
# 455    31.0
# 456    31.0
# 457     NaN
# Name: Age, Length: 458, dtype: float64

# %%
nba["Salary"].div(1000000)
nba["Salary in millions"]=nba["Salary"]/100000 
#Adding a new row and using divide function to convert salary in millions

# %%
nba.head(3)
# Out:
#             Name            Team  Number       Sport  \
# 0  Avery Bradley  Boston Celtics     0.0  Basketball
# 1    Jae Crowder  Boston Celtics    99.0  Basketball
# 2   John Holland  Boston Celtics    30.0  Basketball
#
#                             League Position   Age Height  Weight  \
# 0  National Basketball Association       PG  25.0    6-2   180.0
# 1  National Basketball Association       SF  25.0    6-6   235.0
# 2  National Basketball Association       SG  27.0    6-5   205.0
#
#              College     Salary  Salary in millions
# 0              Texas  7730337.0            77.30337
# 1          Marquette  6796117.0            67.96117
# 2  Boston University        NaN                 NaN

# %%
nba["Team"].value_counts()
# Out:
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Milwaukee Bucks           16
# New York Knicks           16
# Los Angeles Lakers        15
# Washington Wizards        15
# Cleveland Cavaliers       15
# Sacramento Kings          15
# Atlanta Hawks             15
# Portland Trail Blazers    15
# Utah Jazz                 15
# Miami Heat                15
# Detroit Pistons           15
# Brooklyn Nets             15
# Los Angeles Clippers      15
# Dallas Mavericks          15
# Denver Nuggets            15
# Houston Rockets           15
# Golden State Warriors     15
# San Antonio Spurs         15
# Oklahoma City Thunder     15
# Boston Celtics            15
# Chicago Bulls             15
# Phoenix Suns              15
# Indiana Pacers            15
# Philadelphia 76ers        15
# Toronto Raptors           15
# Charlotte Hornets         15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: Team, dtype: int64

# %%
#dropna to remove the null value

# %%
nba["Salary"].fillna(0,inplace = True) #fill the Null value by the value given i.e. 0

# %%
nba.head()
# Out:
#             Name            Team  Number       Sport  \
# 0  Avery Bradley  Boston Celtics     0.0  Basketball
# 1    Jae Crowder  Boston Celtics    99.0  Basketball
# 2   John Holland  Boston Celtics    30.0  Basketball
# 3    R.J. Hunter  Boston Celtics    28.0  Basketball
# 4  Jonas Jerebko  Boston Celtics     8.0  Basketball
#
#                             League Position   Age Height  Weight  \
# 0  National Basketball Association       PG  25.0    6-2   180.0
# 1  National Basketball Association       SF  25.0    6-6   235.0
# 2  National Basketball Association       SG  27.0    6-5   205.0
# 3  National Basketball Association       SG  22.0    6-5   185.0
# 4  National Basketball Association       PF  29.0   6-10   231.0
#
#              College     Salary  Salary in millions
# 0              Texas  7730337.0            77.30337
# 1          Marquette  6796117.0            67.96117
# 2  Boston University        0.0                 NaN
# ...

# %%
nba["Salary"].astype("int") #astype to change float to int
# Out:
# 0      7730337.0
# 1      6796117.0
# 2            0.0
# 3      1148640.0
# 4      5000000.0
#          ...
# 453    2433333.0
# 454     900000.0
# 455    2900000.0
# 456     947276.0
# 457          0.0
# Name: Salary, Length: 458, dtype: float64

# %%
nba.sort_values("Name", ascending = False) #sorting in descending values
# Out:
#                 Name                    Team  Number       Sport  \
# 237    Zaza Pachulia        Dallas Mavericks    27.0  Basketball
# 271    Zach Randolph       Memphis Grizzlies    50.0  Basketball
# 402      Zach LaVine  Minnesota Timberwolves     8.0  Basketball
# 270   Xavier Munford       Memphis Grizzlies    14.0  Basketball
# 386  Wilson Chandler          Denver Nuggets    21.0  Basketball
# ..               ...                     ...     ...         ...
# 404    Adreian Payne  Minnesota Timberwolves    33.0  Basketball
# 328   Aaron Harrison       Charlotte Hornets     9.0  Basketball
# 356     Aaron Gordon           Orlando Magic     0.0  Basketball
# 152     Aaron Brooks           Chicago Bulls     0.0  Basketball
# 457              NaN                     NaN     NaN  Basketball
#
#                               League Position   Age Height  Weight  \
# 237  National Basketball Association        C  32.0   6-11   275.0
# ...

# %%
nba.sort_values(["Team","Name"]) #sorting two columns
# Out:
#                 Name                Team  Number       Sport  \
# 312       Al Horford       Atlanta Hawks    15.0  Basketball
# 318  Dennis Schroder       Atlanta Hawks    17.0  Basketball
# 323      Jeff Teague       Atlanta Hawks     0.0  Basketball
# 309    Kent Bazemore       Atlanta Hawks    24.0  Basketball
# 311     Kirk Hinrich       Atlanta Hawks    12.0  Basketball
# ..               ...                 ...     ...         ...
# 376  Markieff Morris  Washington Wizards     5.0  Basketball
# 375     Nene Hilario  Washington Wizards    42.0  Basketball
# 378  Otto Porter Jr.  Washington Wizards    22.0  Basketball
# 379   Ramon Sessions  Washington Wizards     7.0  Basketball
# 457              NaN                 NaN     NaN  Basketball
#
#                               League Position   Age Height  Weight  \
# 312  National Basketball Association        C  30.0   6-10   245.0
# 318  National Basketball Association       PG  22.0    6-1   172.0
# ...

# %%
nba.sort_values(["Number","Salary","Name"],inplace = True)
nba.tail()
# Out:
#                Name                Team  Number       Sport  \
# 372     Drew Gooden  Washington Wizards    90.0  Basketball
# 5      Amir Johnson      Boston Celtics    90.0  Basketball
# 68   Lucas Nogueira     Toronto Raptors    92.0  Basketball
# 1       Jae Crowder      Boston Celtics    99.0  Basketball
# 457             NaN                 NaN     NaN  Basketball
#
#                               League Position   Age Height  Weight    College  \
# 372  National Basketball Association       PF  34.0   6-10   250.0     Kansas
# 5    National Basketball Association       PF  29.0    6-9   240.0        NaN
# 68   National Basketball Association        C  23.0    7-0   220.0        NaN
# 1    National Basketball Association       SF  25.0    6-6   235.0  Marquette
# 457  National Basketball Association      NaN   NaN    NaN     NaN        NaN
#
#          Salary  Salary in millions
# 372   3300000.0            33.00000
# 5    12000000.0           120.00000
# ...

# %%
nba.sort_index(ascending=False,inplace = True)
nba.head(3)
# Out:
#              Name       Team  Number       Sport  \
# 457           NaN        NaN     NaN  Basketball
# 456   Jeff Withey  Utah Jazz    24.0  Basketball
# 455  Tibor Pleiss  Utah Jazz    21.0  Basketball
#
#                               League Position   Age Height  Weight College  \
# 457  National Basketball Association      NaN   NaN    NaN     NaN     NaN
# 456  National Basketball Association        C  26.0    7-0   231.0  Kansas
# 455  National Basketball Association        C  26.0    7-3   256.0     NaN
#
#         Salary  Salary in millions
# 457        0.0                 NaN
# 456   947276.0             9.47276
# 455  2900000.0            29.00000

# %%
nba.dropna(how = "all")
nba["Salary"]=nba["Salary"].fillna(0).astype("int")
nba.head(3)
# Out:
#              Name       Team  Number       Sport  \
# 457           NaN        NaN     NaN  Basketball
# 456   Jeff Withey  Utah Jazz    24.0  Basketball
# 455  Tibor Pleiss  Utah Jazz    21.0  Basketball
#
#                               League Position   Age Height  Weight College  \
# 457  National Basketball Association      NaN   NaN    NaN     NaN     NaN
# 456  National Basketball Association        C  26.0    7-0   231.0  Kansas
# 455  National Basketball Association        C  26.0    7-3   256.0     NaN
#
#       Salary  Salary in millions
# 457        0                 NaN
# 456   947276             9.47276
# 455  2900000            29.00000

# %%
nba["Salary Rank"]=nba["Salary"].rank(ascending=False).astype("int")
nba.head(3)
# Out:
#              Name       Team  Number       Sport  \
# 457           NaN        NaN     NaN  Basketball
# 456   Jeff Withey  Utah Jazz    24.0  Basketball
# 455  Tibor Pleiss  Utah Jazz    21.0  Basketball
#
#                               League Position   Age Height  Weight College  \
# 457  National Basketball Association      NaN   NaN    NaN     NaN     NaN
# 456  National Basketball Association        C  26.0    7-0   231.0  Kansas
# 455  National Basketball Association        C  26.0    7-3   256.0     NaN
#
#       Salary  Salary in millions  Slary Rank  Salary Rank
# 457        0                 NaN         452          452
# 456   947276             9.47276         367          367
# 455  2900000            29.00000         214          214
